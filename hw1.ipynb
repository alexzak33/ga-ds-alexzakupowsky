# %% [markdown]
# # Homework Assignment #1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Section 1: Police Killings

# %%
killings = pd.read_csv('../data/police-killings.csv', index_col=[0])
killings.head()
# Out:
#                  name  age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington   16   Male            Black  February   23  2015
# 1      Aaron Rutledge   27   Male            White     April    2  2015
# 2         Aaron Siler   26   Male            White     March   14  2015
# 3        Aaron Valdez   25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic   29   Male            White     March   19  2015
#
#             streetaddress          city state  \
# 0            Clearview Ln     Millbrook    AL
# 1  300 block Iris Park Dr     Pineville    LA
# 2    22nd Ave and 56th St       Kenosha    WI
# 3       3000 Seminole Ave    South Gate    CA
# 4          364 Hiwood Ave  Munroe Falls    OH
#
#               lawenforcementagency    cause    armed  county_income
# 0      Millbrook Police Department  Gunshot       No          54766
# 1  Rapides Parish Sheriff's Office  Gunshot       No          40930
# ...

# %% [markdown]
# ### 1. Make the following changes to column names:
#
# - Rename "lawenforcementagency" to "agency"
# - Rename "raceethnicity" to "race"

# %%
killings.rename(columns={'lawenforcementagency':'agency'}, inplace=True)
killings.head(500)
# Out:
#                         name  age  gender    raceethnicity     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
killings.isnull().sum()
# Out:
# name             0
# age              0
# gender           0
# raceethnicity    0
# month            0
# day              0
# year             0
# streetaddress    4
# city             0
# state            0
# agency           0
# cause            0
# armed            0
# county_income    0
# dtype: int64

# %% [markdown]
# ### 3. Replace each null/missing value in the dataframe with the string "unknown"

# %%
killings.fillna('unknown')
# Out:
#                         name  age  gender    raceethnicity     month  day  \
# 0         A'donte Washington   16    Male            Black  February   23
# 1             Aaron Rutledge   27    Male            White     April    2
# 2                Aaron Siler   26    Male            White     March   14
# 3               Aaron Valdez   25    Male  Hispanic/Latino     March   11
# 4               Adam Jovicic   29    Male            White     March   19
# 5              Adam Reinhart   29    Male            White     March    7
# 6           Adrian Hernandez   22    Male  Hispanic/Latino     March   27
# 7               Adrian Solis   35    Male  Hispanic/Latino     March   26
# 8              Alan Alverson   44    Male            White   January   28
# 9                 Alan James   31    Male            White  February    7
# 10          Albert Hanson Jr   76    Male            White     April   26
# 11            Alec Ouzounian   40    Male            White       May   12
# ...

# %% [markdown]
# ### 4. How many killings were there in March and April?

# %%
killings.groupby('month').count()
# Out:
#           name  age  gender  raceethnicity  day  year  streetaddress  city  \
# month
# April       96   96      96             96   96    96             94    96
# February    84   84      84             84   84    84             84    84
# January     90   90      90             90   90    90             89    90
# June         2    2       2              2    2     2              2     2
# March      114  114     114            114  114   114            113   114
# May         81   81      81             81   81    81             81    81
#
#           state  agency  cause  armed  county_income
# month
# April        96      96     96     96             96
# February     84      84     84     84             84
# January      90      90     90     90             90
# June          2       2      2      2              2
# March       114     114    114    114            114
# May          81      81     81     81             81

# %% [markdown]
# ### 5. How many male and how many female victims are there?

# %%
killings.groupby('gender').count()
# Out:
#         name  age  raceethnicity  month  day  year  streetaddress  city  \
# gender
# Female    22   22             22     22   22    22             22    22
# Male     445  445            445    445  445   445            441   445
#
#         state  agency  cause  armed  county_income
# gender
# Female     22      22     22     22             22
# Male      445     445    445    445            445

# %% [markdown]
# ### 6. How many killings were of unarmed people?

# %%
killings.groupby('armed').count()
# Out:
#                     name  age  gender  raceethnicity  month  day  year  \
# armed
# Disputed               2    2       2              2      2    2     2
# Firearm              230  230     230            230    230  230   230
# Knife                 68   68      68             68     68   68    68
# No                   102  102     102            102    102  102   102
# Non-lethal firearm    14   14      14             14     14   14    14
# Other                 26   26      26             26     26   26    26
# Unknown                7    7       7              7      7    7     7
# Vehicle               18   18      18             18     18   18    18
#
#                     streetaddress  city  state  agency  cause  county_income
# armed
# Disputed                        2     2      2       2      2              2
# Firearm                       227   230    230     230    230            230
# Knife                          68    68     68      68     68             68
# ...

# %% [markdown]
# ### 7. What percentage of all killings were unarmed?

# %%
killings.count()
killings.groupby('armed').count()
killings.groupby('armed').size() * 100 / killings.shape[0]
# Out:
# armed
# Disputed               0.428266
# Firearm               49.250535
# Knife                 14.561028
# No                    21.841542
# Non-lethal firearm     2.997859
# Other                  5.567452
# Unknown                1.498929
# Vehicle                3.854390
# dtype: float64

# %% [markdown]
# ### 8. What are the 5 states with the most killings?

# %%
killings.groupby('state').count()
# Out:
#        name  age  gender  raceethnicity  month  day  year  streetaddress  \
# state
# AK        2    2       2              2      2    2     2              2
# AL        8    8       8              8      8    8     8              8
# AR        4    4       4              4      4    4     4              4
# AZ       25   25      25             25     25   25    25             25
# CA       74   74      74             74     74   74    74             74
# CO       12   12      12             12     12   12    12             12
# CT        1    1       1              1      1    1     1              1
# DC        1    1       1              1      1    1     1              1
# DE        2    2       2              2      2    2     2              2
# FL       29   29      29             29     29   29    29             29
# GA       16   16      16             16     16   16    16             16
# HI        4    4       4              4      4    4     4              4
# ...

# %% [markdown]
# ### 9. Show a value counts of deaths for each race

# %%
killings.groupby('raceethnicity').count()
# Out:
#                         name  age  gender  month  day  year  streetaddress  \
# raceethnicity
# Asian/Pacific Islander    10   10      10     10   10    10             10
# Black                    135  135     135    135  135   135            134
# Hispanic/Latino           67   67      67     67   67    67             66
# Native American            4    4       4      4    4     4              4
# Unknown                   15   15      15     15   15    15             15
# White                    236  236     236    236  236   236            234
#
#                         city  state  agency  cause  armed  county_income
# raceethnicity
# Asian/Pacific Islander    10     10      10     10     10             10
# Black                    135    135     135    135    135            135
# Hispanic/Latino           67     67      67     67     67             67
# Native American            4      4       4      4      4              4
# ...

# %%
killings["month"].value_counts().plot(kind = "bar")

# %% [markdown]
# ### 10. Display a histogram of ages of all killings

# %%
killings.hist(column='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1146ead50>]], dtype=object)

# %% [markdown]
# ### 11. Show histogram of ages for each race

# %%
killings.hist(column='age',by='raceethnicity',bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115c07050>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1160ac410>]], dtype=object)

# %% [markdown]
# ### 12. What is the average age of death by race?

# %%
killings.groupby('raceethnicity').mean()
# Out:
#                               age        day    year  county_income
# raceethnicity
# Asian/Pacific Islander  40.800000  11.700000  2015.0   62696.800000
# Black                   34.044444  15.081481  2015.0   54181.881481
# Hispanic/Latino         31.716418  16.985075  2015.0   53257.328358
# Native American         27.750000  19.500000  2015.0   50723.500000
# Unknown                 43.533333  17.866667  2015.0   53725.466667
# White                   40.466102  15.915254  2015.0   50897.139831

# %% [markdown]
# ### 13. Show a bar chart with counts of deaths every month

# %%
killings.plot.bar(x=None, y=None)

# %% [markdown]
# ## Section 2: College Majors

# %%
majors = pd.read_csv('../data/college-majors.csv', index_col=[0])
majors.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %% [markdown]
# ### 1. Delete the columns (employed_full_time_year_round, major_code)

# %%
majors.drop('Major_code', axis=1)
majors.drop('Employed_full_time_year_round', axis=1)
# Out:
#      Major_code                                              Major  \
# 0          1100                                GENERAL AGRICULTURE
# 1          1101              AGRICULTURE PRODUCTION AND MANAGEMENT
# 2          1102                             AGRICULTURAL ECONOMICS
# 3          1103                                    ANIMAL SCIENCES
# 4          1104                                       FOOD SCIENCE
# 5          1105                         PLANT SCIENCE AND AGRONOMY
# 6          1106                                       SOIL SCIENCE
# 7          1199                          MISCELLANEOUS AGRICULTURE
# 8          1301                              ENVIRONMENTAL SCIENCE
# 9          1302                                           FORESTRY
# 10         1303                       NATURAL RESOURCES MANAGEMENT
# 11         1401                                       ARCHITECTURE
# 12         1501               AREA ETHNIC AND CIVILIZATION STUDIES
# ...

# %% [markdown]
# ### 2. Show the count of missing values in each column

# %%
majors.isnull().sum(axis=0)
# Out:
# Major_code                       0
# Major                            0
# Major_category                   0
# Total                            0
# Employed                         0
# Employed_full_time_year_round    0
# Unemployed                       0
# Unemployment_rate                0
# Median                           0
# P25th                            0
# P75th                            0
# dtype: int64

# %% [markdown]
# ### 3. What are the top 10 highest paying majors?

# %%
majors.sort_values(by=['Median'], ascending=False).head(10)
# Out:
#      Major_code                                              Major  \
# 59         2419                              PETROLEUM ENGINEERING
# 154        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 57         2417          NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 55         2415                          METALLURGICAL ENGINEERING
# 58         2418                                NUCLEAR ENGINEERING
# 56         2416                     MINING AND MINERAL ENGINEERING
# 97         4005                   MATHEMATICS AND COMPUTER SCIENCE
# 48         2408                             ELECTRICAL ENGINEERING
# 45         2405                               CHEMICAL ENGINEERING
# 51         2411             GEOLOGICAL AND GEOPHYSICAL ENGINEERING
#
#               Major_category   Total  Employed  Employed_full_time_year_round  \
# 59               Engineering   19631     14002                          11636
# ...

# %% [markdown]
# ### 4. Plot the data from the last question in a bar chart, include proper title, and labels

# %%
barC=majors.sort_values(by=['Median'], ascending=False).head(10)
barC.plot.bar(x= 'Major', y='Median')

# %% [markdown]
# ### 5. What is the average median salary for each major category?

# %%
majors.groupby('Major_category').median()
# Out:
#                                      Major_code     Total  Employed  \
# Major_category
# Agriculture & Natural Resources          1104.5   74428.0   55635.5
# Arts                                     6003.5  154162.5  121361.0
# Biology & Life Science                   3605.5   36686.5   26846.0
# Business                                 6206.0  187274.0  142879.0
# Communications & Journalism              1902.5  314658.5  242456.0
# Computers & Mathematics                  2106.0   51771.0   44071.0
# Education                                2308.5  153384.0  109809.5
# Engineering                              2413.0   37382.0   27275.0
# Health                                   6105.5   91081.5   65404.0
# Humanities & Liberal Arts                3402.0  103740.0   75798.0
# Industrial Arts & Consumer Services      4101.0   92346.0   79055.0
# Interdisciplinary                        4000.0   45199.0   35706.0
# Law & Public Policy                      5301.0   54636.0   37879.0
# ...

# %% [markdown]
# ### 6. Visualize only the top 5 paying major categories

# %%
majorY =majors.groupby('Major_category').median()
majorY.sort_values('Median', ascending=False).head(5)
# Out:
#                                  Major_code     Total  Employed  \
# Major_category
# Engineering                          2413.0   37382.0   27275.0
# Computers & Mathematics              2106.0   51771.0   44071.0
# Business                             6206.0  187274.0  142879.0
# Physical Sciences                    5004.5   13108.5   10406.0
# Agriculture & Natural Resources      1104.5   74428.0   55635.5
#
#                                  Employed_full_time_year_round  Unemployed  \
# Major_category
# Engineering                                            22104.0      1521.0
# Computers & Mathematics                                35954.0      2748.0
# Business                                              118249.0      8862.0
# Physical Sciences                                       8168.0       583.5
# Agriculture & Natural Resources                        45104.0      2107.0
#
#                                  Unemployment_rate   Median    P25th     P75th
# Major_category
# ...

# %% [markdown]
# ### 7. Plot a histogram of the distribution of median salaries

# %%
majors.hist(column='Median', by='Major_category')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e0afed0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e948410>]], dtype=object)

# %% [markdown]
# ### 8. Plot a histogram of the distribution of median salaries by major category

# %%
majors.hist('Median', column='Major_category', by=None, grid=True, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=None, layout=None, bins=10,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-266-21851aba8142> in <module>()
# ----> 1 majors.hist('Median', column='Major_category', by=None, grid=True, xrot=None, ylabelsize=None, yrot=None, ax=None, sharex=False, sharey=False, figsize=None, layout=None, bins=10,)
#
# TypeError: hist_frame() got multiple values for keyword argument 'column'

# %% [markdown]
# ### 9. What are the top 10 most UNemployed majors?

# %%
majors.sort_values(by='Unemployed', ascending=False).head(10)
# Out:
#      Major_code                                   Major  \
# 161        6203  BUSINESS MANAGEMENT AND ADMINISTRATION
# 158        6200                        GENERAL BUSINESS
# 114        5200                              PSYCHOLOGY
# 159        6201                              ACCOUNTING
# 13         1901                          COMMUNICATIONS
# 73         3301         ENGLISH LANGUAGE AND LITERATURE
# 164        6206        MARKETING AND MARKETING RESEARCH
# 132        5506        POLITICAL SCIENCE AND GOVERNMENT
# 25         2300                       GENERAL EDUCATION
# 78         3600                                 BIOLOGY
#
#                   Major_category    Total  Employed  \
# 161                     Business  3123510   2354398
# 158                     Business  2148712   1580978
# 114     Psychology & Social Work  1484075   1055854
# 159                     Business  1779219   1335825
# 13   Communications & Journalism   987676    790696
# ...

# %% [markdown]
# ### 10. What are the top 10 most UNemployed majors CATEGORIES? Use the mean for each category

# %%
majorUn =majors.groupby('Major_category').mean()
majorUn.sort_values('Unemployed', ascending=False).head(10)
# Out:
#                               Major_code          Total       Employed  \
# Major_category
# Business                     6213.000000  758364.692308  579219.307692
# Communications & Journalism  1902.500000  450955.500000  355760.250000
# Social Science               5348.000000  294902.777778  207978.111111
# Arts                         6015.125000  225733.125000  163586.875000
# Humanities & Liberal Arts    4048.600000  249222.333333  166611.666667
# Psychology & Social Work     5258.111111  220808.666667  156887.000000
# Law & Public Policy          4501.400000  180585.200000  143784.800000
# Education                    2387.687500  293757.375000  177074.937500
# Computers & Mathematics      2702.727273  161943.454545  128237.000000
# Health                       5937.916667  245904.916667  182724.333333
#
#                              Employed_full_time_year_round    Unemployed  \
# Major_category
# Business                                     474717.384615  33415.153846
# ...

# %% [markdown]
# ## Section 3: FIFA Soccer Game data

# %%
fifa = pd.read_csv('../data/fifa_data.csv')
fifa.head()
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#       ...      Long_Shots Curve Freekick_Accuracy Penalties  Volleys  \
# ...

# %% [markdown]
# ### 1. Clean up the dataset.
#
#     - Lowercase the column names
#     - Set the "name" column as the index
#     - Drop the following columns "national_position", "national_kit", "club_kit", "club_joining", and "contract_expiry"
#     - Get rid of all players who are goalkeepers and drop every column that starts with GK
#     - Drop every player whose rating is less than 70
#     - Convert the "height" and "weight" columns to float types
#     - Check to see if there any nulls, if so drop them from the dataset

# %%
fifa.columns = fifa.columns.str.lower()

# %%
fifa.set_index('name')
# Out:
#                             nationality national_position  national_kit  \
# name
# Cristiano Ronaldo              Portugal                LS           7.0
# Lionel Messi                  Argentina                RW          10.0
# Neymar                           Brazil                LW          10.0
# Luis Suárez                     Uruguay                LS           9.0
# Manuel Neuer                    Germany                GK           1.0
# De Gea                            Spain                GK           1.0
# Robert Lewandowski               Poland                LS           9.0
# Gareth Bale                       Wales                RS          11.0
# Zlatan Ibrahimović               Sweden               NaN           NaN
# Thibaut Courtois                Belgium                GK           1.0
# Jérôme Boateng                  Germany               RCB          17.0
# Eden Hazard                     Belgium                LF          10.0
# ...

# %%
fifa.drop(['gk_positioning', 'gk_diving', 'gk_kicking', 'gk_handling', 'gk_reflexes'], axis=1).head(4)
# Out:
#                 name nationality  national_kit          club club_position  \
# 0  Cristiano Ronaldo    Portugal           7.0   Real Madrid            LW
# 1       Lionel Messi   Argentina          10.0  FC Barcelona            RW
# 2             Neymar      Brazil          10.0  FC Barcelona            LW
# 3        Luis Suárez     Uruguay           9.0  FC Barcelona            ST
#
#    club_kit club_joining  contract_expiry  rating  height   ...    agility  \
# 0       7.0   07/01/2009           2021.0      94  185 cm   ...         90
# 1      10.0   07/01/2004           2018.0      93  170 cm   ...         90
# 2      11.0   07/01/2013           2021.0      92  174 cm   ...         96
# 3       9.0   07/11/2014           2021.0      92  182 cm   ...         86
#
#   jumping heading  shot_power finishing long_shots  curve  freekick_accuracy  \
# 0      95      85          92        93         90     81                 76
# ...

# %%
fifa.sort_values('rating', ascending=True).head(50)
inExp = fifa['rating'] < 70
fifa.drop['inExp']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-224-036613173fd4> in <module>()
#       1 fifa.sort_values('rating', ascending=True).head(50)
#       2 inExp = fifa['rating'] < 70
# ----> 3 fifa.drop['inExp']
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %%
fifa.dtypes
# Out:
# name                   object
# nationality            object
# national_kit          float64
# club                   object
# club_position          object
# club_kit              float64
# club_joining           object
# contract_expiry       float64
# rating                  int64
# height                 object
# weight                 object
# preffered_foot         object
# birth_date             object
# age                     int64
# preffered_position     object
# work_rate              object
# weak_foot               int64
# skill_moves             int64
# ball_control            int64
# dribbling               int64
# marking                 int64
# sliding_tackle          int64
# standing_tackle         int64
# aggression              int64
# reactions               int64
# attacking_position      int64
# interceptions           int64
# vision                  int64
# composure               int64
# crossing                int64
# short_pass              int64
# ...

# %%
hdata = fifa['height']
hdata.loc['height']
hdata.astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-244-6e9177e5fb31> in <module>()
#       1 hdata = fifa['height']
# ----> 2 hdata.loc['height']
#       3 hdata.astype(float)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_type(self, key, axis)
# ...

# %%
fifa.dropna(subset=['national_position'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-f37b32afcec0> in <module>()
# ----> 1 fifa.dropna(subset=['national_position'], inplace=True)
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in dropna(self, axis, how, thresh, subset, inplace)
#    3050                 check = indices == -1
#    3051                 if check.any():
# -> 3052                     raise KeyError(list(np.compress(check, subset)))
#    3053                 agg_obj = self.take(indices, axis=agg_axis)
#    3054
#
# KeyError: ['national_position']

# %%
fifa.groupby('club_position').head()
fifa.sort_values(by='national_position')
fifa.drop
# Out:
#                          name          nationality national_position  \
# 1235             Breel Embolo          Switzerland               CAM
# 7143         Abdallah El-Said                Egypt               CAM
# 1565             Wes Hoolahan  Republic of Ireland               CAM
# 431              Josip Iličić             Slovenia               CAM
# 2168          Nicolae Stanciu              Romania               CAM
# 455               Yunus Mallı               Turkey               CAM
# 197                 Dele Alli              England               CAM
# 496       Jonathan dos Santos               Mexico               CAM
# 854            James McArthur             Scotland               CAM
# 817              Ivelin Popov             Bulgaria               CAM
# 19          Antoine Griezmann               France               CAM
# 2234         Alexandr Erokhin               Russia               CAM
# 756    Konstantinos Fortounis               Greece               CAM
# ...

# %% [markdown]
# ### 2.  Who are the top five players of the following attributes: speed, marking, and finishing

# %%
TopF= fifa.drop(['national_kit','birth_date', 'height','weight','preffered_foot', 'preffered_position', 'weak_foot','skill_moves','ball_control','work_rate','age','club_kit', 'club_joining', 'contract_expiry','gk_positioning', 'gk_diving', 'gk_kicking', 'gk_handling', 'gk_reflexes'], axis=1).head(50)

# %%
TopF.sort_values(by='marking', ascending=False).head(5)
# Out:
#                  name nationality             club club_position  rating  \
# 27  Giorgio Chiellini       Italy         Juventus           LCB      88
# 15       Thiago Silva      Brazil              PSG           LCB      89
# 10     Jérôme Boateng     Germany        FC Bayern           Sub      89
# 29               Pepe    Portugal      Real Madrid           RCB      88
# 24        Diego Godín     Uruguay  Atlético Madrid           LCB      88
#
#     dribbling  marking  sliding_tackle  standing_tackle  aggression   ...     \
# 27         56       92              90               92          90   ...
# 15         68       90              89               91          77   ...
# 10         67       90              91               92          82   ...
# 29         58       88              89               87          94   ...
# 24         53       87              89               86          86   ...
#
#     agility  jumping  heading  shot_power  finishing  long_shots  curve  \
# ...

# %%
TopF.sort_values(by='speed', ascending=False).head(5)
# Out:
#                          name nationality           club club_position  \
# 35  Pierre-Emerick Aubameyang       Gabon  Bor. Dortmund            ST
# 7                 Gareth Bale       Wales    Real Madrid            RW
# 0           Cristiano Ronaldo    Portugal    Real Madrid            LW
# 21                 Marco Reus     Germany  Bor. Dortmund            LW
# 2                      Neymar      Brazil   FC Barcelona            LW
#
#     rating  dribbling  marking  sliding_tackle  standing_tackle  aggression  \
# 35      87         82       28              36               25          45
# 7       90         89       51              52               55          65
# 0       94         92       22              23               31          63
# 21      88         86       30              46               36          49
# 2       92         96       21              33               24          56
#
#      ...     agility  jumping  heading  shot_power  finishing  long_shots  \
# ...

# %%
TopF.sort_values(by='finishing', ascending=False).head(5)
# Out:
#                   name nationality          club club_position  rating  \
# 1         Lionel Messi   Argentina  FC Barcelona            RW      93
# 3          Luis Suárez     Uruguay  FC Barcelona            ST      92
# 0    Cristiano Ronaldo    Portugal   Real Madrid            LW      94
# 14     Gonzalo Higuaín   Argentina      Juventus            ST      89
# 6   Robert Lewandowski      Poland     FC Bayern            ST      90
#
#     dribbling  marking  sliding_tackle  standing_tackle  aggression   ...     \
# 1          97       13              26               28          48   ...
# 3          86       30              38               45          78   ...
# 0          92       22              23               31          63   ...
# 14         84       12              18               22          50   ...
# 6          85       25              19               42          80   ...
#
#     agility  jumping  heading  shot_power  finishing  long_shots  curve  \
# ...

# %%
fifa.dropna()
# Out:
#                           name          nationality  national_kit  \
# 0            Cristiano Ronaldo             Portugal           7.0
# 1                 Lionel Messi            Argentina          10.0
# 2                       Neymar               Brazil          10.0
# 3                  Luis Suárez              Uruguay           9.0
# 4                 Manuel Neuer              Germany           1.0
# 5                       De Gea                Spain           1.0
# 6           Robert Lewandowski               Poland           9.0
# 7                  Gareth Bale                Wales          11.0
# 9             Thibaut Courtois              Belgium           1.0
# 10              Jérôme Boateng              Germany          17.0
# 11                 Eden Hazard              Belgium          10.0
# 13                  Mesut Özil              Germany          10.0
# 14             Gonzalo Higuaín            Argentina           9.0
# ...

# %% [markdown]
# ### 3. Who is the tallest French lefted foot player?

# %%
FLP = fifa.drop(['contract_expiry', 'national_kit', 'club_joining', 'gk_positioning', 'gk_diving', 'gk_kicking', 'gk_handling', 'gk_reflexes'], axis=1).head(50)
FLP.sort_values(by='nationality', ascending=True)
FLP.sort_values(by='height', ascending=False)
#Hugo Lloris (GK) or Antoine Griezmann
# Out:
#                          name     nationality             club club_position  \
# 9            Thibaut Courtois         Belgium          Chelsea            GK
# 30                  Petr Čech  Czech Republic          Arsenal            GK
# 8          Zlatan Ibrahimović          Sweden   Manchester Utd            ST
# 41                      Piqué           Spain     FC Barcelona           RCB
# 4                Manuel Neuer         Germany        FC Bayern            GK
# 5                      De Gea           Spain   Manchester Utd            GK
# 40           Samir Handanovič        Slovenia            Inter            GK
# 10             Jérôme Boateng         Germany        FC Bayern           Sub
# 31           Gianluigi Buffon           Italy         Juventus            GK
# 25               Mats Hummels         Germany        FC Bayern           LCB
# 18                 Paul Pogba          France   Manchester Utd           LCM
# ...

# %% [markdown]
# ### 4. Show a pandas series of every attribute's correlation with the rating attribute

# %%
fifa.drop(['contract_expiry', 'national_kit', 'club_joining', 'gk_positioning', 'gk_diving', 'gk_kicking', 'gk_handling', 'gk_reflexes'], axis=1).head(4)
# Out:
#                 name nationality          club club_position  club_kit  \
# 0  Cristiano Ronaldo    Portugal   Real Madrid            LW       7.0
# 1       Lionel Messi   Argentina  FC Barcelona            RW      10.0
# 2             Neymar      Brazil  FC Barcelona            LW      11.0
# 3        Luis Suárez     Uruguay  FC Barcelona            ST       9.0
#
#    rating  height weight preffered_foot  birth_date   ...     agility jumping  \
# 0      94  185 cm  80 kg          Right  02/05/1985   ...          90      95
# 1      93  170 cm  72 kg           Left  06/24/1987   ...          90      68
# 2      92  174 cm  68 kg          Right  02/05/1992   ...          96      61
# 3      92  182 cm  85 kg          Right  01/24/1987   ...          86      69
#
#   heading  shot_power  finishing  long_shots  curve  freekick_accuracy  \
# 0      85          92         93          90     81                 76
# 1      71          85         95          88     89                 90
# ...

# %% [markdown]
# ### 5. Make a heatmap of the dataset's correlation table

# %% [markdown]
# ### 6. Return a dataframe with only players from the following clubs. Call the dataframe fifa2. From now on we'll be using fifa2

# %%
clubs_list = ['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
              'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
              'Bor. Dortmund', 'Liverpool', 'Roma']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-303-47ac6c6c8381> in <module>()
#       1 fifa.groupby['Real Madrid', 'FC Barcelona', 'FC Bayern', 'Manchester Utd',
#       2               'Chelsea', 'Arsenal', 'Juventus', 'PSG', 'Manchester City',
# ----> 3               'Bor. Dortmund', 'Liverpool', 'Roma'].head()
#
# TypeError: 'instancemethod' object has no attribute '__getitem__'

# %% [markdown]
# ### 7. Make a bar plot of the average long_shots, curve, and dribbling attributes of the clubs in the data

# %% [markdown]
# ### 8. Make a scatter plot of short_pass vs marking and use the preffered_foot column to color-encode the dots.
